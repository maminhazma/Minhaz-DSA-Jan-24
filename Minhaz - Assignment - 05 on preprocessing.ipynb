# %%
# Minhaz M A

# %%
# Assignment on Preprocessing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as stat

# %% [markdown]
# #1 Loading data

# %%
data = pd.read_csv(r"C:\Users\mamin\Downloads\titanic_dataset.csv") # load the data set

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# duplicating data set set for working
data1 = data.copy()

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #2

# %%
# making PassengerId as index column
data1.set_index("PassengerId", inplace=True)

# %%
data1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# #3 Basic information

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data1.describe() # to get the details of numerical column
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data1.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 887             False   False  False  False  False  False  False   False
# 888             False   False  False  False  False  False  False   False
# 889             False   False  False  False   True  False  False   False
# 890             False   False  False  False  False  False  False   False
# 891             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# ...

# %%
data1.isnull().sum() # to find the missing values in any column
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# #4 Fill in missing values

# %%
#To fill the missing values in column Age, Cabin, Embarked

# %%
mean_age = data1['Age'].mean() # age missing values replace with mean of the column
data1['Age'].fillna(mean_age, inplace=True)

# %%
mode_cabin = data1['Cabin'].mode() # cabin missing value replace with mode value
print (mode_cabin)
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %%
mode_cabin_fill = mode_cabin.iloc[2] # cabin missing value replace with 3rd mode value
data1['Cabin'].fillna(mode_cabin_fill, inplace=True)

# %%
mode_embarked = data1['Embarked'].mode() # embarked missing value replace withe mode value
print (mode_embarked)
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
mode_embarked_fill = mode_embarked[0] # embarked missing value replace with first mode value
data1['Embarked'].fillna(mode_embarked_fill, inplace=True)

# %%
data1.isnull().sum() # all missing values cleared
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# #5 Outliers handling

# %%
# Checking for column Age

# %%
plt.boxplot(x=data['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22aa0dbb690>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22a947c98d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22aa0df7390>],
#  'medians': [<matplotlib.lines.Line2D at 0x22aa05c0850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22aa0de7150>],
#  'means': []}

# %%
# not getting the plot 
#

# %% [markdown]
# #6 Min max scaling

# %%
data1.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
data1['Survived'].describe() # Survived as target
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
min_scaler = MinMaxScaler()

# %%
data1_scaling= data1.drop(['Name','Cabin','Embarked','Ticket','Sex'],axis=1)

# %%
data_scaled = min_scaler.fit_transform(data1_scaling)

# %%
data_scaled_new = pd.DataFrame(data_scaled)
data_scaled_new.head()
# Out:
#      0    1         2      3    4         5
# 0  0.0  1.0  0.271174  0.125  0.0  0.014151
# 1  1.0  0.0  0.472229  0.125  0.0  0.139136
# 2  1.0  1.0  0.321438  0.000  0.0  0.015469
# 3  1.0  0.0  0.434531  0.125  0.0  0.103644
# 4  0.0  1.0  0.434531  0.000  0.0  0.015713
